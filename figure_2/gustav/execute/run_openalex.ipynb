# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append(
    './../src'
)

from preparator import openalex

# %%
# %%time
# openalex.publishers()

# %%
# %%time
# openalex.institutions()

# %%
# %%time
# openalex.concepts()

# %%
# %%time
# openalex.sources()

# %%
# %%time
# openalex.authors()

# %%
# %%time
openalex.works()
# Out:
# /Volumes/active_gustav_and_supplements/ACTIVE_gustav_big_data/input/manual/openalex/2023-02-27b/data/works/updated_date=2023-02-21/part_000.gz
# pubmed_id
# pmc_id
# neither
# /Volumes/active_gustav_and_supplements/ACTIVE_gustav_big_data/input/manual/openalex/2023-02-27b/data/works/updated_date=2023-02-21/part_001.gz
# pubmed_id
# pmc_id
# neither
# /Volumes/active_gustav_and_supplements/ACTIVE_gustav_big_data/input/manual/openalex/2023-02-27b/data/works/updated_date=2023-02-21/part_002.gz
# pubmed_id
# pmc_id
# neither
# /Volumes/active_gustav_and_supplements/ACTIVE_gustav_big_data/input/manual/openalex/2023-02-27b/data/works/updated_date=2023-02-21/part_003.gz
# pubmed_id
# pmc_id
# neither
# /Volumes/active_gustav_and_supplements/ACTIVE_gustav_big_data/input/manual/openalex/2023-02-27b/data/works/updated_date=2023-02-21/part_004.gz
# pubmed_id
# pmc_id
# neither
# ...
